# %% [markdown]
# <a href="https://colab.research.google.com/github/swistak7171/175IC-machine-learning/blob/master/zad.6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt

# 1
data = load_iris()
input = data['data'][:, :2]
output = data['target']

# 2
x_train, x_test, y_train, y_test = train_test_split(input, output)

# 3
def plot(C, kernel):
  svc = SVC(C=C, kernel=kernel)
  svc.fit(x_train, y_train)
  plot_decision_regions(x_train, y_train, clf=svc, legend=2)
  prediction = svc.predict(x_test)
  accuracy = svc.score(x_test, y_test)
  
  plt.title(f"SVC: train accuracy: {accuracy}")
  plt.xlabel('petal length (cm)')
  plt.ylabel('petal width (cm)')
  plt.show()

plot(0.1, 'sigmoid')

# 4
plot(0.7, 'rbf')
plot(0.99, 'linear')
plot(0.25, 'poly')
# Out:
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
# ...
